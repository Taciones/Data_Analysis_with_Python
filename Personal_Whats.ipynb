# %%
import pandas as pd
import csv



#with open('whats.txt', 'r',encoding='UTF-8') as File:
#    data = File.read()
    

headers = ["index","time","person","message"]


#df = pd.read_csv('whats.txt',sep = " ",names = headers)
df = pd.read_csv('whats.txt', delimiter = "\t",names = headers)
#df = pd.read_fwf('whats.txt')
#df=pd.read_csv("whats.txt",delimiter="\t")
#df = pd.read_csv('whats.txt', delimiter= '\s+', index_col=False)

# %%
df.head(1000)
# Out:
#                                                  index time person message
# 0    [26/06/18 14:52:16] Naja: ‎Messages to this ch...  NaN    NaN     NaN
# 1                        [26/06/18 14:52:16] Naja: Moo  NaN    NaN     NaN
# 2        [26/06/18 14:52:25] Naja: Add meu número novo  NaN    NaN     NaN
# 3     ‎[26/06/18 14:59:09] Naja: ‎Contact card omitted  NaN    NaN     NaN
# 4      [26/06/18 14:59:30] Naja: Segue meu novo número  NaN    NaN     NaN
# 5    ‎[26/06/18 14:59:43] Tacio Degrazia: ‎image om...  NaN    NaN     NaN
# 6            [26/06/18 15:12:45] Naja: hauhaua verdade  NaN    NaN     NaN
# 7    [26/06/18 15:12:56] Naja: mas moor nao apaga a...  NaN    NaN     NaN
# 8    [26/06/18 15:17:17] Tacio Degrazia: não... nos...  NaN    NaN     NaN
# 9    [26/06/18 15:17:27] Tacio Degrazia: volta e me...  NaN    NaN     NaN
# 10                    [26/06/18 15:17:33] Naja: huahua  NaN    NaN     NaN
# ...

# %%
missing_data = df.isnull()

# %%
missing_data.head()
# Out:
#    index  time  person  message
# 0  False  True    True     True
# 1  False  True    True     True
# 2  False  True    True     True
# 3  False  True    True     True
# 4  False  True    True     True

# %%
for column in missing_data.columns.values.tolist():
    print(column)
    print (missing_data[column].value_counts())
    print("")
# Out:
# index
# False    34980
# Name: index, dtype: int64
#
# time
# True     34951
# False       29
# Name: time, dtype: int64
#
# person
# True     34979
# False        1
# Name: person, dtype: int64
#
# message
# True     34979
# False        1
# Name: message, dtype: int64

# %%
df.drop(["time","person","message"], axis=1, inplace=True)

# %%
df.head()
# Out:
#                                                index
# 0  [26/06/18 14:52:16] Naja: ‎Messages to this ch...
# 1                      [26/06/18 14:52:16] Naja: Moo
# 2      [26/06/18 14:52:25] Naja: Add meu número novo
# 3   ‎[26/06/18 14:59:09] Naja: ‎Contact card omitted
# 4    [26/06/18 14:59:30] Naja: Segue meu novo número

# %%
df['date'] = df['index'].str.extract('(../../..)', expand=True)
df['date']
df.head(50)
# Out:
#                                                 index      date      time
# 0   [26/06/18 14:52:16] Naja: ‎Messages to this ch...  26/06/18  14:52:16
# 1                       [26/06/18 14:52:16] Naja: Moo  26/06/18  14:52:16
# 2       [26/06/18 14:52:25] Naja: Add meu número novo  26/06/18  14:52:25
# 3    ‎[26/06/18 14:59:09] Naja: ‎Contact card omitted  26/06/18  14:59:09
# 4     [26/06/18 14:59:30] Naja: Segue meu novo número  26/06/18  14:59:30
# 5   ‎[26/06/18 14:59:43] Tacio Degrazia: ‎image om...  26/06/18  14:59:43
# 6           [26/06/18 15:12:45] Naja: hauhaua verdade  26/06/18  15:12:45
# 7   [26/06/18 15:12:56] Naja: mas moor nao apaga a...  26/06/18  15:12:56
# 8   [26/06/18 15:17:17] Tacio Degrazia: não... nos...  26/06/18  15:17:17
# 9   [26/06/18 15:17:27] Tacio Degrazia: volta e me...  26/06/18  15:17:27
# 10                   [26/06/18 15:17:33] Naja: huahua  26/06/18  15:17:33
# 11  [26/06/18 15:17:38] Tacio Degrazia: escutando ...  26/06/18  15:17:38
# ...

# %%
df['time'] = df['index'].str.extract('(..:..:..)', expand=True)

# %%
df.head()
# Out:
#                                                index      date      time
# 0  [26/06/18 14:52:16] Naja: ‎Messages to this ch...  26/06/18  14:52:16
# 1                      [26/06/18 14:52:16] Naja: Moo  26/06/18  14:52:16
# 2      [26/06/18 14:52:25] Naja: Add meu número novo  26/06/18  14:52:25
# 3   ‎[26/06/18 14:59:09] Naja: ‎Contact card omitted  26/06/18  14:59:09
# 4    [26/06/18 14:59:30] Naja: Segue meu novo número  26/06/18  14:59:30

# %%
df.to_csv('newtext.txt')

# %%
import numpy as np
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
text = open('whats_csv.csv').read()
wordcloud = WordCloud().generate(text)
# Generate plot
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white").generate(text)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
